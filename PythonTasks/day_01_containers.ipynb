# %%
ai_related_words = ["Nural Network","NLP","Computer Vision","LLMs","Deep_Learning"]

ai_related_words[1] = "Natural Language Processing"
print("", ai_related_words)

ai_related_words.append("Machine Learning")
print("", ai_related_words)

mixed_data = [42, "Saad", True, [1,2,3]]
mixed_data[3][2]
print(ai_related_words)
len(ai_related_words)
ai_related_words.append("Khamba Chor")
print(ai_related_words)
ai_related_words.insert(6,"Zarek Tia")
print(ai_related_words)
# Out:
# The 2nd element is  NLP
# The 4th element is  LLMs
# The last element is  Deep_Learning
# The subset is ['NLP', 'Computer Vision', 'LLMs']
#  ['Nural Network', 'Natural Language Processing', 'Computer Vision', 'LLMs', 'Deep_Learning']
#  ['Nural Network', 'Natural Language Processing', 'Computer Vision', 'LLMs', 'Deep_Learning', 'Machine Learning']
# ['Nural Network', 'Natural Language Processing', 'Computer Vision', 'LLMs', 'Deep_Learning', 'Machine Learning']
# ['Nural Network', 'Natural Language Processing', 'Computer Vision', 'LLMs', 'Deep_Learning', 'Machine Learning', 'Khamba Chor']
# ['Nural Network', 'Natural Language Processing', 'Computer Vision', 'LLMs', 'Deep_Learning', 'Machine Learning', 'Zarek Tia', 'Khamba Chor']
